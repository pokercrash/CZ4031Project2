# %%
import dash
import dash_bootstrap_components as dbc
from dash import Input, Output, dcc, html, callback, dash_table
import pandas as pd
import plotly.express as px

app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])
df = pd.DataFrame({
    "Plan": ['1','2','3','4'],
    "Amount": [4, 1, 2, 9]
})




fig = px.bar(df, x="Plan", y="Amount", color="Amount", barmode="group")

def process_select(select_statement):
    text = select_statement.strip().upper()
    list_of_breakdown = []
    for x in impt_breakers:
        if len(text.split(x)) == 2:
            a,b = text.split(x)
            text = x + " " + b
            list_of_breakdown += [a.strip()]
    list_of_breakdown += [text]
    list1 = [x+1 for x in range(len(list_of_breakdown)-1)]
    return pd.DataFrame({"line":list1, "query":list_of_breakdown[1:]})

select_statement = "select * \n from customer C, orders O \n where C.c_custkey = O.o_custkey"
query_df = process_select(select_statement)

# the style arguments for the sidebar. We use position:fixed and a fixed width
SIDEBAR_STYLE = {
    "position": "fixed",
    "top": 0,
    "left": 0,
    "bottom": 0,
    "width": "30rem",
    "padding": "2rem 1rem",
    "background-color": "#f8f9fa",
}

# the styles for the main content position it to the right of the sidebar and
# add some padding.
CONTENT_STYLE = {
    "margin-left": "30rem",
    "margin-right": "2rem",
    "padding": "2rem 1rem",
}

sidebar = html.Div(
    [
        html.H2("DBP Query \nOptimiser", className="display-4"),
        html.Hr(),
        html.P(
            "Input", className="lead"
        ),
        dcc.Textarea(
        id='textarea-example',
        placeholder='Input SQL Query here ...',
        style={'width': '100%', 'height': 300},
    ),
    html.Div(id='textarea-example-output', style={'whiteSpace': 'pre-line'}),
        dbc.Button('Submit', id='submit-val', n_clicks=0)
    ],
    
    style=SIDEBAR_STYLE,
)

content = html.Div([
    dcc.Dropdown(['Choice A','Choice B'],'Choice B',id = 'dropdown'),
    dcc.Graph(
        id='example-graph',
        figure=fig
    ),dbc.Label('Click a cell in the table:'),
    dash_table.DataTable(query_df.to_dict('records'),[{"name": i, "id": i} for i in query_df.columns], id='tbl'),
    dbc.Alert(id='tbl_out')],style=CONTENT_STYLE)

app.layout = html.Div([dcc.Location(id="url"), sidebar, content])

impt_breakers = ['SELECT','FROM', 'WHERE','JOIN','GROUP BY']
@app.callback(
    Output('example-graph', 'figure'),
    Output('tbl', 'data'),
    Output('submit-val', 'n_clicks'),
    [Input('dropdown', 'value'),
     Input('textarea-example', 'value'),
     Input('submit-val', 'n_clicks')
    ])
def user_model(dropdown_value,text,submit_val):
    if submit_val !=0 :
        return fig,process_select(text).to_dict('records'),0


@callback(Output('tbl_out', 'children'), Input('tbl', 'active_cell'))
def update_graphs(active_cell):
    return "This join is implemented using hash join operator as NL joins and merge join increase the estimated cost by at least 10 and 7 times, respectively." if active_cell else "Click the table"



if __name__ == "__main__":
    app.run_server(debug = False,port=8051)
# Out:
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8051/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/Nov/2022 23:14:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Nov/2022 23:14:32] "GET /_dash-component-suites/dash/dash_table/async-highlight.js HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Nov/2022 23:14:32] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Nov/2022 23:14:32] "GET /_dash-component-suites/dash/dash_table/async-table.js HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Nov/2022 23:14:32] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Nov/2022 23:14:32] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [05/Nov/2022 23:14:32] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Nov/2022 23:14:32] "GET /_dash-dependencies HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# 127.0.0.1 - - [05/Nov/2022 23:14:32] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# 127.0.0.1 - - [05/Nov/2022 23:14:32] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
# ...
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# 127.0.0.1 - - [05/Nov/2022 23:46:48] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.9/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py", line 1261, in dispatch
#     ctx.run(
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_callback.py", line 455, in add_context
#     flat_output_values = flatten_grouping(output_value, output)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 35, in flatten_grouping
#     validate_grouping(grouping, schema)
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 210, in validate_grouping
#     SchemaTypeValidationError.check(grouping, full_schema, path, (tuple, list))
#   File "/opt/anaconda3/lib/python3.9/site-packages/dash/_grouping.py", line 162, in check
#     raise SchemaTypeValidationError(value, full_schema, path, expected_type)
# dash._grouping.SchemaTypeValidationError: Schema: [<Output `example-graph.figure`>, <Output `tbl.data`>, <Output `submit-val.n_clicks`>]
# Path: ()
# Expected type: (<class 'tuple'>, <class 'list'>)
# Received value of type <class 'NoneType'>:
#     None
# 127.0.0.1 - - [05/Nov/2022 23:46:48] "POST /_dash-update-component HTTP/1.1" 500 -

# %%
import dash
import dash_bootstrap_components as dbc
from dash import Input, Output, dcc, html, callback, dash_table
import pandas as pd
import plotly.express as px

# %%
impt_breakers = ['SELECT','FROM', 'WHERE','JOIN','GROUP BY']
text = "select * \n from customer C, orders O \n where C.c_custkey = O.o_custkey".upper()
list_of_breakdown = []
for x in impt_breakers:
    if len(text.split(x)) == 2:
        a,b = text.split(x)
        text = x + " " + b
        list_of_breakdown += [a.strip()]
list_of_breakdown += [text]
print(list_of_breakdown)
# Out:
# ['', 'SELECT  *', 'FROM  CUSTOMER C, ORDERS O', 'WHERE  C.C_CUSTKEY = O.O_CUSTKEY']

# %%
import json
import tkinter as tk
from tkinter import font, ttk, messagebox
from typing import Text
import interface
from node_types import ATTRIBUTE
import sqlparse
import node_types
import psycopg2
import annotation
import dash
import dash_bootstrap_components as dbc
from dash import Input, Output, dcc, html, callback, dash_table
import pandas as pd
import plotly.express as px

json1 = interface.get_json("select l_orderkey, o_orderdate, o_shippriority from customer, orders, lineitem where c_mktsegment = 'BUILDING' and c_custkey = o_custkey and l_orderkey = o_orderkey and o_totalprice < 50000 and l_extendedprice > 1200 ")
# Out:
# [([{'Plan': {'Node Type': 'Gather', 'Parallel Aware': False, 'Async Capable': False, 'Startup Cost': 5521.03, 'Total Cost': 116577.63, 'Plan Rows': 167853, 'Plan Width': 12, 'Actual Startup Time': 35.073, 'Actual Total Time': 5713.395, 'Actual Rows': 58341, 'Actual Loops': 1, 'Output': ['lineitem.l_orderkey', 'orders.o_orderdate', 'orders.o_shippriority'], 'Workers Planned': 2, 'Workers Launched': 2, 'Single Copy': False, 'Plans': [{'Node Type': 'Nested Loop', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Join Type': 'Inner', 'Startup Cost': 4521.03, 'Total Cost': 98792.33, 'Plan Rows': 69939, 'Plan Width': 12, 'Actual Startup Time': 26.645, 'Actual Total Time': 5678.462, 'Actual Rows': 19447, 'Actual Loops': 3, 'Output': ['lineitem.l_orderkey', 'orders.o_orderdate', 'orders.o_shippriority'], 'Inner Unique': False, 'Workers': [{'Worker Number': 0, 'Actual Startup Time': 22.904, 'Actual Total Time': 5677.751, 'Actual Rows': 19337, 'Actual Loops': 1}, {'Worker Number': 1, 'Actual Startup Time': 22.684, 'Actual Total Time': 5679.612, 'Actual Rows': 19450, 'Actual Loops': 1}], 'Plans': [{'Node Type': 'Hash Join', 'Parent Relationship': 'Outer', 'Parallel Aware': True, 'Async Capable': False, 'Join Type': 'Inner', 'Startup Cost': 4520.6, 'Total Cost': 38661.55, 'Plan Rows': 17569, 'Plan Width': 12, 'Actual Startup Time': 26.516, 'Actual Total Time': 641.497, 'Actual Rows': 14360, 'Actual Loops': 3, 'Output': ['orders.o_orderdate', 'orders.o_shippriority', 'orders.o_orderkey'], 'Inner Unique': True, 'Hash Cond': '(orders.o_custkey = customer.c_custkey)', 'Workers': [{'Worker Number': 0, 'Actual Startup Time': 22.753, 'Actual Total Time': 632.447, 'Actual Rows': 14306, 'Actual Loops': 1}, {'Worker Number': 1, 'Actual Startup Time': 22.547, 'Actual Total Time': 637.505, 'Actual Rows': 14367, 'Actual Loops': 1}], 'Plans': [{'Node Type': 'Seq Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': True, 'Async Capable': False, 'Relation Name': 'orders', 'Schema': 'public', 'Alias': 'orders', 'Startup Cost': 0.0, 'Total Cost': 33907.5, 'Plan Rows': 88929, 'Plan Width': 16, 'Actual Startup Time': 0.057, 'Actual Total Time': 536.592, 'Actual Rows': 70382, 'Actual Loops': 3, 'Output': ['orders.o_orderkey', 'orders.o_custkey', 'orders.o_orderstatus', 'orders.o_totalprice', 'orders.o_orderdate', 'orders.o_orderpriority', 'orders.o_clerk', 'orders.o_shippriority', 'orders.o_comment'], 'Filter': "(orders.o_totalprice < '50000'::numeric)", 'Rows Removed by Filter': 429618, 'Workers': [{'Worker Number': 0, 'Actual Startup Time': 0.072, 'Actual Total Time': 531.424, 'Actual Rows': 70253, 'Actual Loops': 1}, {'Worker Number': 1, 'Actual Startup Time': 0.034, 'Actual Total Time': 536.001, 'Actual Rows': 70390, 'Actual Loops': 1}]}, {'Node Type': 'Hash', 'Parent Relationship': 'Inner', 'Parallel Aware': True, 'Async Capable': False, 'Startup Cost': 4366.25, 'Total Cost': 4366.25, 'Plan Rows': 12348, 'Plan Width': 4, 'Actual Startup Time': 26.145, 'Actual Total Time': 26.146, 'Actual Rows': 10047, 'Actual Loops': 3, 'Output': ['customer.c_custkey'], 'Hash Buckets': 32768, 'Original Hash Buckets': 32768, 'Hash Batches': 1, 'Original Hash Batches': 1, 'Peak Memory Usage': 1472, 'Workers': [{'Worker Number': 0, 'Actual Startup Time': 22.305, 'Actual Total Time': 22.305, 'Actual Rows': 8687, 'Actual Loops': 1}, {'Worker Number': 1, 'Actual Startup Time': 22.284, 'Actual Total Time': 22.285, 'Actual Rows': 8657, 'Actual Loops': 1}], 'Plans': [{'Node Type': 'Seq Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': True, 'Async Capable': False, 'Relation Name': 'customer', 'Schema': 'public', 'Alias': 'customer', 'Startup Cost': 0.0, 'Total Cost': 4366.25, 'Plan Rows': 12348, 'Plan Width': 4, 'Actual Startup Time': 0.042, 'Actual Total Time': 21.765, 'Actual Rows': 10047, 'Actual Loops': 3, 'Output': ['customer.c_custkey'], 'Filter': "(customer.c_mktsegment = 'BUILDING'::bpchar)", 'Rows Removed by Filter': 39953, 'Wor ...
# success

# %%
dict1 = json.loads(json1[3:-3])

# %%
import newinterface
text = "select * from customer C, orders O where C.c_custkey = O.o_custkey"
node_list = newinterface.execute_query(text)
# Out:
# [([{'Plan': {'Node Type': 'Hash Join', 'Parallel Aware': False, 'Async Capable': False, 'Join Type': 'Inner', 'Startup Cost': 10330.0, 'Total Cost': 108538.61, 'Plan Rows': 1500000, 'Plan Width': 266, 'Actual Startup Time': 145.575, 'Actual Total Time': 2887.351, 'Actual Rows': 1500000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment', 'o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment'], 'Inner Unique': True, 'Hash Cond': '(o.o_custkey = c.c_custkey)', 'Plans': [{'Node Type': 'Seq Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Relation Name': 'orders', 'Schema': 'public', 'Alias': 'o', 'Startup Cost': 0.0, 'Total Cost': 41095.0, 'Plan Rows': 1500000, 'Plan Width': 107, 'Actual Startup Time': 0.067, 'Actual Total Time': 342.032, 'Actual Rows': 1500000, 'Actual Loops': 1, 'Output': ['o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment']}, {'Node Type': 'Hash', 'Parent Relationship': 'Inner', 'Parallel Aware': False, 'Async Capable': False, 'Startup Cost': 5085.0, 'Total Cost': 5085.0, 'Plan Rows': 150000, 'Plan Width': 159, 'Actual Startup Time': 145.127, 'Actual Total Time': 145.128, 'Actual Rows': 150000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment'], 'Hash Buckets': 65536, 'Original Hash Buckets': 65536, 'Hash Batches': 4, 'Original Hash Batches': 4, 'Peak Memory Usage': 7642, 'Plans': [{'Node Type': 'Seq Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Relation Name': 'customer', 'Schema': 'public', 'Alias': 'c', 'Startup Cost': 0.0, 'Total Cost': 5085.0, 'Plan Rows': 150000, 'Plan Width': 159, 'Actual Startup Time': 0.013, 'Actual Total Time': 27.941, 'Actual Rows': 150000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment']}]}]}, 'Planning Time': 1.768, 'Triggers': [], 'Execution Time': 3017.231}],)]
# success
# tokenized line: ['SELECT', '*']
# appending token: *, pos: (6, 7)
# appending token: *, pos: (8, 8)
# tokenized line: ['FROM', 'customer', 'C', '']
# appending token: customer, pos: (13, 23)
# tokenized line: ['', '', '', '', '', 'orders', 'O']
# appending token: orders, pos: (30, 38)
# appending token: O, pos: (37, 39)
# tokenized line: ['WHERE', 'C.c_custkey', '=', 'O.o_custkey']
# appending token: C.c_custkey, pos: (45, 58)
# appending token: =, pos: (57, 60)
# appending token: O.o_custkey, pos: (59, 71)
# Tokens:{'*': (8, 8), 'customer': (13, 23), 'orders': (30, 38), 'O': (37, 39), 'C.c_custkey': (45, 58), '=': (57, 60), 'O.o_custkey': (59, 71)}
# jump
# [([{'Plan': {'Node Type': 'Gather', 'Parallel Aware': False, 'Async Capable': False, 'Startup Cost': 1000.43, 'Total Cost': 415041.07, 'Plan Rows': 1500000, 'Plan Width': 266, 'Actual Startup Time': 0.83, 'Actual Total Time': 2691.613, 'Actual Rows': 1500000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment', 'o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment'], 'Workers Planned': 2, 'Workers Launched': 2, 'Single Copy': False, 'Plans': [{'Node Type': 'Nested Loop', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Join Type': 'Inner', 'Startup Cost': 0.43, 'Total Cost': 264041.07, 'Plan Rows': 625000, 'Plan Width': 266, 'Actual Startup Time': 0.181, 'Actual Total Time': 2459.941, 'Actual Rows': 500000, 'Actual Loops': 3, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment', 'o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment'], 'Inner Unique': True, 'Workers': [{'Worker Number': 0, 'Actual Startup Time': 0.181, 'Actual Total Time': 2479.776, 'Actual Rows': 505489, 'Actual Loops': 1}, {'Worker Number': 1, 'Actual Startup Time': 0.181, 'Actual Total Time': 2472.244, 'Actual Rows': 507033, 'Actual Loops': 1}], 'Plans': [{'Node Type': 'Seq Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': True, 'Async Capable': False, 'Relation Name': 'orders', 'Schema': 'public', 'Alias': 'o', 'Startup Cost': 0.0, 'Total Cost': 32345.0, 'Plan Rows': 625000, 'Plan Width': 107, 'Actual Startup Time': 0.099, 'Actual Total Time': 150.233, 'Actual Rows': 500000, 'Actual Loops': 3, 'Output': ['o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment'], 'Workers': [{'Worker Number': 0, 'Actual Startup Time': 0.108, 'Actual Total Time': 150.388, 'Actual Rows': 505489, 'Actual Loops': 1}, {'Worker Number': 1, 'Actual Startup Time': 0.111, 'Actual Total Time': 155.351, 'Actual Rows': 507033, 'Actual Loops': 1}]}, {'Node Type': 'Memoize', 'Parent Relationship': 'Inner', 'Parallel Aware': False, 'Async Capable': False, 'Startup Cost': 0.43, 'Total Cost': 0.46, 'Plan Rows': 1, 'Plan Width': 159, 'Actual Startup Time': 0.004, 'Actual Total Time': 0.004, 'Actual Rows': 1, 'Actual Loops': 1500000, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment'], 'Cache Key': 'o.o_custkey', 'Cache Mode': 'logical', 'Cache Hits': 164501, 'Cache Misses': 322977, 'Cache Evictions': 290943, 'Cache Overflows': 0, 'Peak Memory Usage': 8193, 'Workers': [{'Worker Number': 0, 'Actual Startup Time': 0.004, 'Actual Total Time': 0.004, 'Actual Rows': 1, 'Actual Loops': 505489, 'Cache Hits': 170259, 'Cache Misses': 335230, 'Cache Evictions': 303204, 'Cache Overflows': 0, 'Peak Memory Usage': 8193}, {'Worker Number': 1, 'Actual Startup Time': 0.004, 'Actual Total Time': 0.004, 'Actual Rows': 1, 'Actual Loops': 507033, 'Cache Hits': 171062, 'Cache Misses': 335971, 'Cache Evictions': 303975, 'Cache Overflows': 0, 'Peak Memory Usage': 8193}], 'Plans': [{'Node Type': 'Index Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Scan Direction': 'Forward', 'Index Name': 'customer_pkey', 'Relation Name': 'customer', 'Schema': 'public', 'Alias': 'c', 'Startup Cost': 0.42, 'Total Cost': 0.45, 'Plan Rows': 1, 'Plan Width': 159, 'Actual Startup Time': 0.004, 'Actual Total Time': 0.004, 'Actual Rows': 1, 'Actual Loops': 994178, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment'], 'Index Cond': '(c.c_custkey = o ...
# success
# [([{'Plan': {'Node Type': 'Gather', 'Parallel Aware': False, 'Async Capable': False, 'Startup Cost': 195920.44, 'Total Cost': 356044.82, 'Plan Rows': 1500000, 'Plan Width': 266, 'Actual Startup Time': 975.533, 'Actual Total Time': 1638.783, 'Actual Rows': 1500000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment', 'o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment'], 'Workers Planned': 2, 'Workers Launched': 2, 'Single Copy': False, 'Plans': [{'Node Type': 'Merge Join', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Join Type': 'Inner', 'Startup Cost': 194920.44, 'Total Cost': 205044.82, 'Plan Rows': 625000, 'Plan Width': 266, 'Actual Startup Time': 966.496, 'Actual Total Time': 1392.437, 'Actual Rows': 500000, 'Actual Loops': 3, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment', 'o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment'], 'Inner Unique': True, 'Merge Cond': '(o.o_custkey = c.c_custkey)', 'Workers': [{'Worker Number': 0, 'Actual Startup Time': 971.423, 'Actual Total Time': 1415.623, 'Actual Rows': 504476, 'Actual Loops': 1}, {'Worker Number': 1, 'Actual Startup Time': 953.021, 'Actual Total Time': 1388.566, 'Actual Rows': 488227, 'Actual Loops': 1}], 'Plans': [{'Node Type': 'Sort', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Startup Cost': 165144.18, 'Total Cost': 166706.68, 'Plan Rows': 625000, 'Plan Width': 107, 'Actual Startup Time': 770.355, 'Actual Total Time': 908.686, 'Actual Rows': 500000, 'Actual Loops': 3, 'Output': ['o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment'], 'Sort Key': ['o.o_custkey'], 'Sort Method': 'external merge', 'Sort Space Used': 59400, 'Sort Space Type': 'Disk', 'Workers': [{'Worker Number': 0, 'Actual Startup Time': 775.077, 'Actual Total Time': 897.513, 'Actual Rows': 504476, 'Actual Loops': 1, 'Sort Method': 'external merge', 'Sort Space Used': 59048, 'Sort Space Type': 'Disk'}, {'Worker Number': 1, 'Actual Startup Time': 761.901, 'Actual Total Time': 926.441, 'Actual Rows': 488227, 'Actual Loops': 1, 'Sort Method': 'external merge', 'Sort Space Used': 57152, 'Sort Space Type': 'Disk'}], 'Plans': [{'Node Type': 'Seq Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': True, 'Async Capable': False, 'Relation Name': 'orders', 'Schema': 'public', 'Alias': 'o', 'Startup Cost': 0.0, 'Total Cost': 32345.0, 'Plan Rows': 625000, 'Plan Width': 107, 'Actual Startup Time': 0.102, 'Actual Total Time': 102.011, 'Actual Rows': 500000, 'Actual Loops': 3, 'Output': ['o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment'], 'Workers': [{'Worker Number': 0, 'Actual Startup Time': 0.125, 'Actual Total Time': 102.715, 'Actual Rows': 504476, 'Actual Loops': 1}, {'Worker Number': 1, 'Actual Startup Time': 0.1, 'Actual Total Time': 101.52, 'Actual Rows': 488227, 'Actual Loops': 1}]}]}, {'Node Type': 'Sort', 'Parent Relationship': 'Inner', 'Parallel Aware': False, 'Async Capable': False, 'Startup Cost': 29775.95, 'Total Cost': 30150.95, 'Plan Rows': 150000, 'Plan Width': 159, 'Actual Startup Time': 196.122, 'Actual Total Time': 245.848, 'Actual Rows': 149999, 'Actual Loops': 3, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment'], 'Sort Key': ['c.c_custkey'], 'Sort Method': 'external merge', 'Sort Space Used': 25280, 'Sort Space Type': 'Disk', 'Workers': [{'Worker Number': 0, 'Actual Sta ...
# success
# 57 60 HASH JOIN  =
# [([{'Plan': {'Node Type': 'Hash Join', 'Parallel Aware': False, 'Async Capable': False, 'Join Type': 'Inner', 'Startup Cost': 10000014379.43, 'Total Cost': 10000112588.04, 'Plan Rows': 1500000, 'Plan Width': 266, 'Actual Startup Time': 159.479, 'Actual Total Time': 2357.688, 'Actual Rows': 1500000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment', 'o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment'], 'Inner Unique': True, 'Hash Cond': '(o.o_custkey = c.c_custkey)', 'Plans': [{'Node Type': 'Seq Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Relation Name': 'orders', 'Schema': 'public', 'Alias': 'o', 'Startup Cost': 10000000000.0, 'Total Cost': 10000041095.0, 'Plan Rows': 1500000, 'Plan Width': 107, 'Actual Startup Time': 0.131, 'Actual Total Time': 274.527, 'Actual Rows': 1500000, 'Actual Loops': 1, 'Output': ['o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment']}, {'Node Type': 'Hash', 'Parent Relationship': 'Inner', 'Parallel Aware': False, 'Async Capable': False, 'Startup Cost': 9134.43, 'Total Cost': 9134.43, 'Plan Rows': 150000, 'Plan Width': 159, 'Actual Startup Time': 158.962, 'Actual Total Time': 158.963, 'Actual Rows': 150000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment'], 'Hash Buckets': 65536, 'Original Hash Buckets': 65536, 'Hash Batches': 4, 'Original Hash Batches': 4, 'Peak Memory Usage': 7642, 'Plans': [{'Node Type': 'Index Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Scan Direction': 'Forward', 'Index Name': 'customer_pkey', 'Relation Name': 'customer', 'Schema': 'public', 'Alias': 'c', 'Startup Cost': 0.42, 'Total Cost': 9134.43, 'Plan Rows': 150000, 'Plan Width': 159, 'Actual Startup Time': 0.027, 'Actual Total Time': 54.337, 'Actual Rows': 150000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment']}]}]}, 'Planning Time': 2.211, 'Triggers': [], 'Execution Time': 2476.788}],)]
# success
# [([{'Plan': {'Node Type': 'Hash Join', 'Parallel Aware': False, 'Async Capable': False, 'Join Type': 'Inner', 'Startup Cost': 20000014379.43, 'Total Cost': 20000112588.04, 'Plan Rows': 1500000, 'Plan Width': 266, 'Actual Startup Time': 138.673, 'Actual Total Time': 2322.747, 'Actual Rows': 1500000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment', 'o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment'], 'Inner Unique': True, 'Hash Cond': '(o.o_custkey = c.c_custkey)', 'Plans': [{'Node Type': 'Seq Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Relation Name': 'orders', 'Schema': 'public', 'Alias': 'o', 'Startup Cost': 10000000000.0, 'Total Cost': 10000041095.0, 'Plan Rows': 1500000, 'Plan Width': 107, 'Actual Startup Time': 0.067, 'Actual Total Time': 277.992, 'Actual Rows': 1500000, 'Actual Loops': 1, 'Output': ['o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment']}, {'Node Type': 'Hash', 'Parent Relationship': 'Inner', 'Parallel Aware': False, 'Async Capable': False, 'Startup Cost': 10000009134.43, 'Total Cost': 10000009134.43, 'Plan Rows': 150000, 'Plan Width': 159, 'Actual Startup Time': 138.212, 'Actual Total Time': 138.214, 'Actual Rows': 150000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment'], 'Hash Buckets': 65536, 'Original Hash Buckets': 65536, 'Hash Batches': 4, 'Original Hash Batches': 4, 'Peak Memory Usage': 7642, 'Plans': [{'Node Type': 'Index Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Scan Direction': 'Forward', 'Index Name': 'customer_pkey', 'Relation Name': 'customer', 'Schema': 'public', 'Alias': 'c', 'Startup Cost': 10000000000.42, 'Total Cost': 10000009134.43, 'Plan Rows': 150000, 'Plan Width': 159, 'Actual Startup Time': 0.02, 'Actual Total Time': 49.94, 'Actual Rows': 150000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment']}]}]}, 'Planning Time': 1.512, 'Triggers': [], 'Execution Time': 2442.429}],)]
# success
# [([{'Plan': {'Node Type': 'Nested Loop', 'Parallel Aware': False, 'Async Capable': False, 'Join Type': 'Inner', 'Startup Cost': 10000000000.44, 'Total Cost': 10004576040.11, 'Plan Rows': 1500000, 'Plan Width': 266, 'Actual Startup Time': 0.147, 'Actual Total Time': 7097.606, 'Actual Rows': 1500000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment', 'o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment'], 'Inner Unique': True, 'Plans': [{'Node Type': 'Seq Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Relation Name': 'orders', 'Schema': 'public', 'Alias': 'o', 'Startup Cost': 10000000000.0, 'Total Cost': 10000041095.0, 'Plan Rows': 1500000, 'Plan Width': 107, 'Actual Startup Time': 0.065, 'Actual Total Time': 302.226, 'Actual Rows': 1500000, 'Actual Loops': 1, 'Output': ['o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment']}, {'Node Type': 'Memoize', 'Parent Relationship': 'Inner', 'Parallel Aware': False, 'Async Capable': False, 'Startup Cost': 0.44, 'Total Cost': 4.45, 'Plan Rows': 1, 'Plan Width': 159, 'Actual Startup Time': 0.004, 'Actual Total Time': 0.004, 'Actual Rows': 1, 'Actual Loops': 1500000, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment'], 'Cache Key': 'o.o_custkey', 'Cache Mode': 'logical', 'Cache Hits': 517937, 'Cache Misses': 982063, 'Cache Evictions': 950034, 'Cache Overflows': 0, 'Peak Memory Usage': 8193, 'Plans': [{'Node Type': 'Bitmap Heap Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Relation Name': 'customer', 'Schema': 'public', 'Alias': 'c', 'Startup Cost': 0.43, 'Total Cost': 4.44, 'Plan Rows': 1, 'Plan Width': 159, 'Actual Startup Time': 0.003, 'Actual Total Time': 0.003, 'Actual Rows': 1, 'Actual Loops': 982063, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment'], 'Recheck Cond': '(c.c_custkey = o.o_custkey)', 'Rows Removed by Index Recheck': 0, 'Exact Heap Blocks': 982063, 'Lossy Heap Blocks': 0, 'Plans': [{'Node Type': 'Bitmap Index Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Index Name': 'customer_pkey', 'Startup Cost': 0.0, 'Total Cost': 0.43, 'Plan Rows': 1, 'Plan Width': 0, 'Actual Startup Time': 0.002, 'Actual Total Time': 0.002, 'Actual Rows': 1, 'Actual Loops': 982063, 'Index Cond': '(c.c_custkey = o.o_custkey)'}]}]}]}, 'Planning Time': 1.475, 'Triggers': [], 'Execution Time': 7230.356}],)]
# success
# [([{'Plan': {'Node Type': 'Hash Join', 'Parallel Aware': False, 'Async Capable': False, 'Join Type': 'Inner', 'Startup Cost': 20000014379.43, 'Total Cost': 20000112588.04, 'Plan Rows': 1500000, 'Plan Width': 266, 'Actual Startup Time': 145.189, 'Actual Total Time': 2324.854, 'Actual Rows': 1500000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment', 'o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment'], 'Inner Unique': True, 'Hash Cond': '(o.o_custkey = c.c_custkey)', 'Plans': [{'Node Type': 'Seq Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Relation Name': 'orders', 'Schema': 'public', 'Alias': 'o', 'Startup Cost': 10000000000.0, 'Total Cost': 10000041095.0, 'Plan Rows': 1500000, 'Plan Width': 107, 'Actual Startup Time': 0.062, 'Actual Total Time': 271.248, 'Actual Rows': 1500000, 'Actual Loops': 1, 'Output': ['o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment']}, {'Node Type': 'Hash', 'Parent Relationship': 'Inner', 'Parallel Aware': False, 'Async Capable': False, 'Startup Cost': 10000009134.43, 'Total Cost': 10000009134.43, 'Plan Rows': 150000, 'Plan Width': 159, 'Actual Startup Time': 144.758, 'Actual Total Time': 144.76, 'Actual Rows': 150000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment'], 'Hash Buckets': 65536, 'Original Hash Buckets': 65536, 'Hash Batches': 4, 'Original Hash Batches': 4, 'Peak Memory Usage': 7642, 'Plans': [{'Node Type': 'Index Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Scan Direction': 'Forward', 'Index Name': 'customer_pkey', 'Relation Name': 'customer', 'Schema': 'public', 'Alias': 'c', 'Startup Cost': 10000000000.42, 'Total Cost': 10000009134.43, 'Plan Rows': 150000, 'Plan Width': 159, 'Actual Startup Time': 0.019, 'Actual Total Time': 51.438, 'Actual Rows': 150000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment']}]}]}, 'Planning Time': 1.57, 'Triggers': [], 'Execution Time': 2446.119}],)]
# success
# 31 37 SEQ SCAN orders
# 30 38 SEQ SCAN  orders
# 14 22 SEQ SCAN customer
# 13 23 SEQ SCAN  customer

# %%
newinterface.get_all_node_labels(text)
# Out:
# [([{'Plan': {'Node Type': 'Hash Join', 'Parallel Aware': False, 'Async Capable': False, 'Join Type': 'Inner', 'Startup Cost': 10330.0, 'Total Cost': 108538.61, 'Plan Rows': 1500000, 'Plan Width': 266, 'Actual Startup Time': 147.921, 'Actual Total Time': 2546.908, 'Actual Rows': 1500000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment', 'o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment'], 'Inner Unique': True, 'Hash Cond': '(o.o_custkey = c.c_custkey)', 'Plans': [{'Node Type': 'Seq Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Relation Name': 'orders', 'Schema': 'public', 'Alias': 'o', 'Startup Cost': 0.0, 'Total Cost': 41095.0, 'Plan Rows': 1500000, 'Plan Width': 107, 'Actual Startup Time': 0.104, 'Actual Total Time': 304.927, 'Actual Rows': 1500000, 'Actual Loops': 1, 'Output': ['o.o_orderkey', 'o.o_custkey', 'o.o_orderstatus', 'o.o_totalprice', 'o.o_orderdate', 'o.o_orderpriority', 'o.o_clerk', 'o.o_shippriority', 'o.o_comment']}, {'Node Type': 'Hash', 'Parent Relationship': 'Inner', 'Parallel Aware': False, 'Async Capable': False, 'Startup Cost': 5085.0, 'Total Cost': 5085.0, 'Plan Rows': 150000, 'Plan Width': 159, 'Actual Startup Time': 147.01, 'Actual Total Time': 147.011, 'Actual Rows': 150000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment'], 'Hash Buckets': 65536, 'Original Hash Buckets': 65536, 'Hash Batches': 4, 'Original Hash Batches': 4, 'Peak Memory Usage': 7642, 'Plans': [{'Node Type': 'Seq Scan', 'Parent Relationship': 'Outer', 'Parallel Aware': False, 'Async Capable': False, 'Relation Name': 'customer', 'Schema': 'public', 'Alias': 'c', 'Startup Cost': 0.0, 'Total Cost': 5085.0, 'Plan Rows': 150000, 'Plan Width': 159, 'Actual Startup Time': 0.022, 'Actual Total Time': 27.227, 'Actual Rows': 150000, 'Actual Loops': 1, 'Output': ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment']}]}]}, 'Planning Time': 2.234, 'Triggers': [], 'Execution Time': 2669.769}],)]
# success
# HASH JOIN
# SEQ SCAN
# Output: ['c.c_custkey', 'c.c_name', 'c.c_address', 'c.c_nationkey', 'c.c_phone', 'c.c_acctbal', 'c.c_mktsegment', 'c.c_comment']
#
# SEQ SCAN

# %%
node_list[0][0]
# Out:
# 'HASH JOIN is  3.8239025725499896 times faster than NESTED LOOP\nHASH JOIN is  3.2803517568540816 times faster than MERGE JOIN\n'

# %%
text = "select * from customer C, orders O where C.c_custkey = O.o_custkey"
impt_breakers = ['SELECT', 'FROM', 'WHERE', 'JOIN', 'GROUP BY', 'ORDER BY']
def process_select(select_statement):
    text = select_statement.strip().upper()
    list_of_breakdown = []
    cutting = []
    oldlen = 0
    for x in impt_breakers:
        if len(text.split(x)) == 2:
            a, b = text.split(x)
            cutting += [len(a.strip())+oldlen]
            oldlen = len(a.strip())
            text = x + " " + b
            list_of_breakdown += [a.strip()]
    list_of_breakdown += [text]
    list1 = [x+1 for x in range(len(list_of_breakdown)-1)]

    return pd.DataFrame({"line": list1, "query": list_of_breakdown[1:]}), cutting
process_select(text)
# Out:
# (   line                             query
#  0     1                         SELECT  *
#  1     2        FROM  CUSTOMER C, ORDERS O
#  2     3  WHERE  C.C_CUSTKEY = O.O_CUSTKEY,
#  [0, 9, 35])

# %%
text[9:35]
# Out:
# 'from customer C, orders O '

# %%
a,b = process_select(text)

# %%
node_list
# Out:
# [['HASH JOIN is  3.8239025725499896 times faster than NESTED LOOP\nHASH JOIN is  3.2803517568540816 times faster than MERGE JOIN\n',
#   60],
#  ['SEQ SCAN is  92134.15012445803 times faster than INDEX SCAN\nSEQ SCAN is  184267.26294025694 times faster than INDEX ONLY SCAN\nSEQ SCAN is  92175.27329776934 times faster than BITMAP SCAN\n',
#   38],
#  ['SEQ SCAN is  92134.15012445803 times faster than INDEX SCAN\nSEQ SCAN is  184267.26294025694 times faster than INDEX ONLY SCAN\nSEQ SCAN is  92175.27329776934 times faster than BITMAP SCAN\n',
#   23]]

# %%
dict1 = {}
def insert_into_dict1(k,v):
    if k not in dict1.keys():
        dict1[k]=[v]
    else:
        dict1[k] += [v]
for x in node_list:
    flag = 0
    for y in range(0,len(b)):
        # print(x[-1],b[y])
        if int(x[-1]) < int(b[y]) and int(x[-1]) > int(b[y-1]) :
            insert_into_dict1(y-1,x[0])
            flag = 1
            break
    if flag == 0:
        insert_into_dict1(y,x[0])
dict1
# Out:
# {2: ['HASH JOIN is  3.8239025725499896 times faster than NESTED LOOP\nHASH JOIN is  3.2803517568540816 times faster than MERGE JOIN\n',
#   'SEQ SCAN is  92134.15012445803 times faster than INDEX SCAN\nSEQ SCAN is  184267.26294025694 times faster than INDEX ONLY SCAN\nSEQ SCAN is  92175.27329776934 times faster than BITMAP SCAN\n'],
#  1: ['SEQ SCAN is  92134.15012445803 times faster than INDEX SCAN\nSEQ SCAN is  184267.26294025694 times faster than INDEX ONLY SCAN\nSEQ SCAN is  92175.27329776934 times faster than BITMAP SCAN\n']}
